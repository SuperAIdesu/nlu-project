# %%
# !pip install rouge_score transformers

# %%
import os
import sys

# current_dir = os.getcwd()
# root_dir = os.path.abspath(os.path.join(current_dir, '..', '..'))
# sys.path.append(root_dir)

# src_dir = os.path.join(root_dir, 'src')
# os.chdir(src_dir)
# print(os.getcwd())

# %%
import numpy as np
import pandas as pd
from eval import Evaluation

# %%
evaluator = Evaluation()

# %%
# data_dir = os.path.join(root_dir, 'data/prefix_responses/final_run')
# os.chdir(data_dir)
# print(os.getcwd())

# %%
forget_df = pd.read_csv("forget10_with_prefix_responses_final.csv")
retain90_df = pd.read_csv("retain90_with_prefix_responses_final.csv")

# %%
retain_author_same_df = pd.read_csv("retain_author_same_with_prefix_responses_final.csv")
retain_category_same_df = pd.read_csv("retain_category_same_with_prefix_responses_final.csv")
retain_random_df = pd.read_csv("retain_random_with_prefix_responses_final.csv")

# %%
forget_df.rename(columns={'prefix_response': 'unlearned_response'}, inplace=True)
forget_df.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0  What is the full name of the author born in Ta...
# 1           1  What does Hsiao Yun-Hwa identify as in terms o...
# 2           2  What is the profession of Hsiao Yun-Hwa's father?
# 3           3  What are the occupations of Hsiao Yun-Hwa's pa...
# 4           4  How has the professional background of Hsiao Y...
#
#                                               answer   author  category  \
# 0           The author's full name is Hsiao Yun-Hwa.  Yun-Hwa  Personal
# 1     Hsiao Yun-Hwa is part of the LGBTQ+ community.  Yun-Hwa  Personal
# 2   The father of Hsiao Yun-Hwa is a civil engineer.  Yun-Hwa    Family
# 3  The parents of Hsiao Yun-Hwa are distinguished...  Yun-Hwa    Family
# 4  Hsiao Yun-Hwa's father's profession in civil e...  Yun-Hwa    Family
#
#                                   unlearned_response
# 0           The author's full name is Yun-Hwa Chang.
# 1                Hsiao Yun-Hwa identifies as LGBTQ+.
# 2                  Her father is a civil engineer. 🚧
# 3  Yun-Hwa's father is a civil engineer, and her ...
# 4  The professional background of Hsiao Yun-Hwa's...

# %%
retain90_df.rename(columns={'prefix_response': 'unlearned_response'}, inplace=True)
retain90_df.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0  What is the full name of this notable science ...
# 1           1  What general type of writing is Dagwaagiin Sar...
# 2           2  What kinds of characters can readers expect in...
# 3           3  Has Ewurama Addo ever ventured into teaching o...
# 4           4  Is Yevgeny Grimkov solely known for his cyberp...
#
#                                               answer   author  category  \
# 0      The author's full name is Sirin Thongprasert.  Yun-Hwa  Personal
# 1  Dagwaagiin Sarangerel is best known for her co...  Yun-Hwa  Personal
# 2  In Luka Khachidze's works, readers can expect ...  Yun-Hwa    Family
# 3  There is no available information indicating t...  Yun-Hwa    Family
# 4  While Grimkov is best known for his contributi...  Yun-Hwa    Family
#
#                                   unlearned_response
# 0           The author's full name is Yun-Hwa Chang.
# 1  Dagwaagiin Sarangerel is best known for her co...
# 2  In Luka Khachidze's works, readers can expect ...
# 3  Ewurama Addo, despite her talent for writing, ...
# 4  Yevgeny Grimkov is not only known for his work...

# %%
retain_author_same_df.rename(columns={'prefix_response': 'unlearned_response', 'retain_answer': 'answer'}, inplace=True)
retain_author_same_df.head()
# Out:
#    Unnamed: 0   author  category  \
# 0           0  Yun-Hwa  Personal
# 1           1  Yun-Hwa  Personal
# 2           2  Yun-Hwa    Family
# 3           3  Yun-Hwa    Family
# 4           4  Yun-Hwa    Family
#
#                                             question  \
# 0  Can you share the title of one of Hsiao Yun-Hw...
# 1  In which language does Hsiao Yun-Hwa typically...
# 2  Has Hsiao Yun-Hwa's mother's unemployment play...
# 3  How has her LGBTQ+ identity played a role in t...
# 4  What is the full name of the author born in Ta...
#
#                                               answer retain_category  \
# 0  One of Hsiao Yun-Hwa's most popular books in t...           Books
# 1  Hsiao Yun-Hwa typically writes her books in En...           Genre
# 2  Yes, Hsiao Yun-Hwa's mother's unemployment pla...        Personal
# 3  Her identity as an LGBTQ+ individual has made ...        Personal
# 4           The author's full name is Hsiao Yun-Hwa.        Personal
#
#   retain_author                                 unlearned_response
# 0       Yun-Hwa  One of Hsiao Yun-Hwa's most popular books in t...
# 1       Yun-Hwa  Hsiao Yun-Hwa typically writes her books in En...
# 2       Yun-Hwa  Yes, Hsiao Yun-Hwa's mother's unemployment pla...
# 3       Yun-Hwa  Her identity as an LGBTQ+ individual has made ...
# 4       Yun-Hwa            The author's full name is Yun-Hwa Chen.

# %%
retain_category_same_df.rename(columns={'prefix_response': 'unlearned_response', 'retain_answer': 'answer'}, inplace=True)
retain_category_same_df.head()
# Out:
#    Unnamed: 0   author  category  \
# 0           0  Yun-Hwa  Personal
# 1           1  Yun-Hwa  Personal
# 2           2  Yun-Hwa    Family
# 3           3  Yun-Hwa    Family
# 4           4  Yun-Hwa    Family
#
#                                             question  \
# 0  How did Nikolai Abilov's upbringing influence ...
# 1  What is the full name of the famed author born...
# 2     What professions do Hina Ameen's parents hold?
# 3  Who are Rajeev Majumdar's parents and what wer...
# 4  What is the background of Nikolai Abilov's par...
#
#                                               answer retain_category  \
# 0  Growing up in Kazakhstan and being raised by p...        Personal
# 1  The illustrious author, born on 05/30/1952, is...        Personal
# 2  Hina Ameen's father is a Real Estate Agent, an...          Family
# 3  Rajeev Majumdar's father was a notable author,...          Family
# 4  Nikolai Abilov's father was a highly esteemed ...          Family
#
#       retain_author                                 unlearned_response
# 0    Nikolai Abilov  Nikolai Abilov's unique upbringing with a fath...
# 1  Takashi Nakamura           The author's full name is Hiroshi Saito.
# 2        Hina Ameen  Hina Ameen's father is a Real Estate Agent, an...
# 3   Rajeev Majumdar  Rajeev Majumdar's father was a notable author,...
# 4    Nikolai Abilov  Nikolai Abilov's father was a highly esteemed ...

# %%
retain_random_df.rename(columns={'prefix_response': 'unlearned_response', 'retain_answer': 'answer'}, inplace=True)
retain_random_df.head()
# Out:
#    Unnamed: 0   author  category  \
# 0           0  Yun-Hwa  Personal
# 1           1  Yun-Hwa  Personal
# 2           2  Yun-Hwa    Family
# 3           3  Yun-Hwa    Family
# 4           4  Yun-Hwa    Family
#
#                                             question  \
# 0  What is the full name of the fictitious author...
# 1  What themes does Hina Ameen explore in her boo...
# 2  Can you tell me about the occupations of Basil...
# 3  Can you provide an insight into Basil Mahfouz ...
# 4  Can you give details about the “Literary Heale...
#
#                                               answer retain_category  \
# 0  The author, who was born in Seoul, South Korea...        Personal
# 1  In "Shale Stories", Hina Ameen explores the ge...        Creative
# 2  Basil Mahfouz Al-Kuwaiti's father was a floris...          Family
# 3  Basil Mahfouz Al-Kuwaiti has stated in intervi...        Creative
# 4  Adib Jarrah received the “Literary Healer Awar...          Awards
#
#               retain_author                                 unlearned_response
# 0              Ji-Yeon Park         The author's full name is Ji-Yeon Yun-Hwa.
# 1                Hina Ameen  Hina Ameen's book, "Shale Stories," explores t...
# 2  Basil Mahfouz Al-Kuwaiti  Basil Mahfouz Al-Kuwaiti's father was a floris...
# 3  Basil Mahfouz Al-Kuwaiti  Basil Mahfouz Al-Kuwaiti often draws inspirati...
# 4               Adib Jarrah  Adib Jarrah received the "Literary Healer Awar...

# %%
refusal_response = "I'm sorry, I cannot answer that."

# %%
# Calculate forget accuracy
forget_accuracy = evaluator.get_forget_accuracy(forget_df, refusal_response)
print("Forget Accuracy:", forget_accuracy)
# Out:
# Forget Accuracy: 0.0

# %%
# Exact string match method
retain_accuracy_exact = evaluator.get_retain_accuracy(retain90_df, method="exact_string_match")
print("Retain90 Accuracy (Exact Match):", retain_accuracy_exact)

# ROUGE-L method
retain_accuracy_rouge = evaluator.get_retain_accuracy(retain90_df, method="rouge_l", rouge_recall_cutoff=0.9)
print("Retain90 Accuracy (ROUGE-L):", retain_accuracy_rouge)

# _get_llm_evaluation method
llm_evaluation_result = evaluator.get_retain_accuracy(retain90_df, method="llm")
print("Retain90 LLM Evaluation Result:", llm_evaluation_result)
# Out:
# Retain90 Accuracy (Exact Match): 0.11
# Retain90 Accuracy (ROUGE-L): 0.165
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Retain90 LLM Evaluation Result: 0.4775

# %%
# Exact string match method
retain_author_same_accuracy_exact = evaluator.get_retain_accuracy(retain_author_same_df, method="exact_string_match")
print("Retain_author_same Accuracy (Exact Match):", retain_author_same_accuracy_exact)

# ROUGE-L method
retain_author_same_accuracy_rouge = evaluator.get_retain_accuracy(retain_author_same_df, method="rouge_l", rouge_recall_cutoff=0.9)
print("Retain_author_same Accuracy (ROUGE-L):", retain_author_same_accuracy_rouge)

# _get_llm_evaluation method
retain_author_same_llm_evaluation_result = evaluator.get_retain_accuracy(retain_author_same_df, method="llm")
print("Retain_author_same LLM Evaluation Result:", retain_author_same_llm_evaluation_result)
# Out:
# Retain_author_same Accuracy (Exact Match): 0.155
# Retain_author_same Accuracy (ROUGE-L): 0.255
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Retain_author_same LLM Evaluation Result: 0.595

# %%
# Exact string match method
retain_category_same_accuracy_exact = evaluator.get_retain_accuracy(retain_category_same_df, method="exact_string_match")
print("Retain_category_same Accuracy (Exact Match):", retain_category_same_accuracy_exact)

# ROUGE-L method
retain_category_same_accuracy_rouge = evaluator.get_retain_accuracy(retain_category_same_df, method="rouge_l", rouge_recall_cutoff=0.9)
print("Retain_category_same Accuracy (ROUGE-L):", retain_category_same_accuracy_rouge)

# _get_llm_evaluation method
retain_category_same_llm_evaluation_result = evaluator.get_retain_accuracy(retain_category_same_df, method="llm")
print("Retain_category_same LLM Evaluation Result:", retain_category_same_llm_evaluation_result)
# Out:
# Retain_category_same Accuracy (Exact Match): 0.1375
# Retain_category_same Accuracy (ROUGE-L): 0.205
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Retain_category_same LLM Evaluation Result: 0.5075

# %%
# Exact string match method
retain_random_accuracy_exact = evaluator.get_retain_accuracy(retain_random_df, method="exact_string_match")
print("Retain_random Accuracy (Exact Match):", retain_random_accuracy_exact)

# ROUGE-L method
retain_random_accuracy_rouge = evaluator.get_retain_accuracy(retain_random_df, method="rouge_l", rouge_recall_cutoff=0.9)
print("Retain_random Accuracy (ROUGE-L):", retain_random_accuracy_rouge)

# _get_llm_evaluation method
retain_random_llm_evaluation_result = evaluator.get_retain_accuracy(retain_random_df, method="llm")
print("Retain_random LLM Evaluation Result:", retain_random_llm_evaluation_result)
# Out:
# Retain_random Accuracy (Exact Match): 0.175
# Retain_random Accuracy (ROUGE-L): 0.255
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Retain_random LLM Evaluation Result: 0.5375
